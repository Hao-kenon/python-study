# %%
import pandas as pd

#创建DataFrame
df1=pd.DataFrame([
    {'姓名':'王林','语文':80,'数学':90,'英语':75},
    {'姓名':'张三','语文':75,'数学':85,'英语':90},
    {'姓名':'李四','语文':85,'数学':95,'英语':80}
])

df2=pd.DataFrame({
    '姓名':['王林','张三','李四'],
    '语文':[80,75,85],
    '数学':[90,85,95],
    '英语':[75,90,80]
})

df3=pd.DataFrame([
    ['王林',80,90,75],
    ['张三',75,85,90],
    ['李四',85,95,80]
],columns=['姓名','语文','数学','英语'])

df4=pd.DataFrame([
    ['王林',80,90,75],
    ['张三',75,85,90],
    ['李四',85,95,80]
],columns=['姓名','语文','数学','英语'],index=['a','b','c'])

#DataFrame 常见属性 - index, columns, values, size, dtypes, shape
# df4.index.tolist() # 索引转换为列表
# df4.columns.tolist() # 列转换为列表
# df4.values.tolist() # 值转换为列表
# df4.size
# df4.dtypes #数据类型
# df4.shape #shape : 维度(行,列)
# Out:
# ['姓名', '语文', '数学', '英语']

# %%
# Series 创建
s1 = pd.Series([10,20,30,40,50])

s2 = pd.Series((10,20,30,40,50),index=['a','b','c','d','e'])

s3 = pd.Series({'a':10,'b':20,'c':30,'d':40,'e':50})

# s1
# s2
# s3

s4 = df4['语文']

#Series 常见属性 - index, columns, values, size, dtypes, shape
# s3.index.tolist() # 索引转换为列表
# s3.values.tolist() # 值转换为列表
# s3.size
# s3.dtypes #数据类型
# s3.shape #shape : 维度(行,)
# Out:
# (5,)
